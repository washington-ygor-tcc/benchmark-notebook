# %%
import nest_asyncio
import numpy as np
import matplotlib.pyplot as plt

from benchmark.application import app, helpers

nest_asyncio.apply()

benchmark_type = helpers.BenchmarkTypes.API
complexity_factor = 1
memory_overhead = 1
requests_number = 10
batch_size = 1
interval = 0
runtime = None
batch_progress = False
total_progress = True


results = app.run_benchmark(
    benchmark_type,
    helpers.batch_generator(
        lambda iteration, time: {
            "complexity_factor": complexity_factor,
            "memory_overhead": memory_overhead,
            "iter": iteration,
        },
        batch_size=batch_size,
        interval=interval,
        total=requests_number,
        runtime=runtime,
    ),
    total=requests_number,
    show_total_progress_bar=total_progress,
    show_batch_progress_bar=batch_progress,
)
# Out:
# Total:   0%|          | 0/10 [00:00<?, ?it/s]
# ([PredictionRequest(request_id='0bae0646bb3e4751b070641c84e1149e', features={'complexity_factor': 1, 'memory_overhead': 1, 'iter': 0}, start=19772.4884807, end=19772.535788504, prediction={'status': 'OK'}),
#   PredictionRequest(request_id='70bc0de66b8d4dcb92be900cd9c4124d', features={'complexity_factor': 1, 'memory_overhead': 1, 'iter': 1}, start=19772.536067642, end=19772.583035859, prediction={'status': 'OK'}),
#   PredictionRequest(request_id='58d72bc357b6499ebbfcf742722baf2c', features={'complexity_factor': 1, 'memory_overhead': 1, 'iter': 2}, start=19772.588031587, end=19772.643283755, prediction={'status': 'OK'}),
#   PredictionRequest(request_id='13da9b47229e4e1d96a7f637064020e9', features={'complexity_factor': 1, 'memory_overhead': 1, 'iter': 3}, start=19772.644349448, end=19772.699535182, prediction={'status': 'OK'}),
# ...

# %%
def plot(requests):
    
    times = sorted(requests[0], key=lambda rq: rq.start)
    
    plt.plot([t.start for t in times],[t.end - t.start for t in times])
    plt.show()

plot(results)
